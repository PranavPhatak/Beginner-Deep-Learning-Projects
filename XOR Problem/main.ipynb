# %%
import numpy as np

# %%
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# %%
y = np.array([
    [0],
    [1],
    [1],
    [0]
])

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def sigmoid_derivative(x):
    return x * (1-x)

# %%
w1 = np.random.randn(2, 2)
b1 = np.zeros((1, 2))

w2 = np.random.randn(2, 1)
b2 = np.zeros((1, 1))

lr = 0.1

# %%
for epoch in range(100000):
    hidden = sigmoid(np.dot(X, w1) + b1)
    output = sigmoid(np.dot(hidden, w2) + b2)

    loss = np.mean((y - output) ** 2)

    output_error = y - output
    output_delta = output_error * sigmoid_derivative(output)

    hidden_error = output_delta.dot(w2.T)
    hidden_delta = hidden_error * sigmoid_derivative(hidden)

    w2 += hidden.T.dot(output_delta) * lr
    b2 += np.sum(output_delta, axis=0, keepdims=True) * lr

    w1 += X.T.dot(hidden_delta) * lr
    b1 += np.sum(hidden_delta, axis=0, keepdims=True) * lr

    if (epoch % 1000 == 0):
        print(f"Epoch {epoch}, Loss: {loss}")

print("Predicted Output: \n", output)
# Out:
# Epoch 0, Loss: 0.12517467253984849
# Epoch 1000, Loss: 0.1251729351348273
# Epoch 2000, Loss: 0.12517123156857385
# Epoch 3000, Loss: 0.12516956086801168
# Epoch 4000, Loss: 0.125167922096862
# Epoch 5000, Loss: 0.12516631435392578
# Epoch 6000, Loss: 0.12516473677146192
# Epoch 7000, Loss: 0.12516318851365282
# Epoch 8000, Loss: 0.12516166877515558
# Epoch 9000, Loss: 0.12516017677972924
# Epoch 10000, Loss: 0.12515871177893634
# Epoch 11000, Loss: 0.12515727305091254
# Epoch 12000, Loss: 0.12515585989920222
# Epoch 13000, Loss: 0.12515447165165292
# Epoch 14000, Loss: 0.12515310765936793
# Epoch 15000, Loss: 0.1251517672957121
# Epoch 16000, Loss: 0.12515044995536792
# Epoch 17000, Loss: 0.12514915505344015
# Epoch 18000, Loss: 0.1251478820246031
# Epoch 19000, Loss: 0.12514663032229256
# Epoch 20000, Loss: 0.12514539941793498
# Epoch 21000, Loss: 0.1251441888002165
# Epoch 22000, Loss: 0.12514299797438538
# Epoch 23000, Loss: 0.1251418264615894
# Epoch 24000, Loss: 0.1251406737982434
# Epoch 25000, Loss: 0.12513953953542767
# Epoch 26000, Loss: 0.12513842323831434
# Epoch 27000, Loss: 0.12513732448561982
# Epoch 28000, Loss: 0.12513624286908331
# Epoch 29000, Loss: 0.1251351779929692
# Epoch 30000, Loss: 0.12513412947359062
# Epoch 31000, Loss: 0.1251330969388565
# Epoch 32000, Loss: 0.12513208002783782
# Epoch 33000, Loss: 0.12513107839035278
# Epoch 34000, Loss: 0.1251300916865715
# Epoch 35000, Loss: 0.12512911958663692
# Epoch 36000, Loss: 0.12512816177030234
# Epoch 37000, Loss: 0.12512721792658546
# Epoch 38000, Loss: 0.12512628775343626
# Epoch 39000, Loss: 0.12512537095741938
# Epoch 40000, Loss: 0.12512446725341
# Epoch 41000, Loss: 0.1251235763643027
# Epoch 42000, Loss: 0.12512269802073167
# Epoch 43000, Loss: 0.12512183196080368
# Epoch 44000, Loss: 0.12512097792984078
# Epoch 45000, Loss: 0.12512013568013491
# Epoch 46000, Loss: 0.1251193049707103
# Epoch 47000, Loss: 0.12511848556709845
# Epoch 48000, Loss: 0.12511767724111972
# Epoch 49000, Loss: 0.12511687977067382
# Epoch 50000, Loss: 0.1251160929395407
# Epoch 51000, Loss: 0.12511531653718608
# Epoch 52000, Loss: 0.125114550358577
# Epoch 53000, Loss: 0.12511379420400404
# Epoch 54000, Loss: 0.12511304787890926
# Epoch 55000, Loss: 0.12511231119372201
# Epoch 56000, Loss: 0.1251115839637006
# Epoch 57000, Loss: 0.1251108660087797
# Epoch 58000, Loss: 0.12511015715342333
# Epoch 59000, Loss: 0.1251094572264846
# Epoch 60000, Loss: 0.12510876606106847
# Epoch 61000, Loss: 0.12510808349440183
# Epoch 62000, Loss: 0.12510740936770692
# Epoch 63000, Loss: 0.12510674352607934
# Epoch 64000, Loss: 0.1251060858183719
# Epoch 65000, Loss: 0.12510543609708097
# Epoch 66000, Loss: 0.12510479421823736
# Epoch 67000, Loss: 0.12510416004130184
# Epoch 68000, Loss: 0.12510353342906388
# Epoch 69000, Loss: 0.12510291424754366
# Epoch 70000, Loss: 0.1251023023658972
# Epoch 71000, Loss: 0.12510169765632656
# Epoch 72000, Loss: 0.12510109999399083
# Epoch 73000, Loss: 0.1251005092569219
# Epoch 74000, Loss: 0.125099925325942
# Epoch 75000, Loss: 0.12509934808458523
# Epoch 76000, Loss: 0.12509877741902015
# Epoch 77000, Loss: 0.12509821321797626
# Epoch 78000, Loss: 0.1250976553726731
# Epoch 79000, Loss: 0.12509710377674998
# Epoch 80000, Loss: 0.1250965583262002
# Epoch 81000, Loss: 0.12509601891930577
# Epoch 82000, Loss: 0.12509548545657556
# Epoch 83000, Loss: 0.12509495784068403
# Epoch 84000, Loss: 0.1250944359764135
# Epoch 85000, Loss: 0.12509391977059706
# Epoch 86000, Loss: 0.12509340913206374
# Epoch 87000, Loss: 0.12509290397158573
# Epoch 88000, Loss: 0.1250924042018269
# Epoch 89000, Loss: 0.12509190973729292
# Epoch 90000, Loss: 0.1250914204942833
# Epoch 91000, Loss: 0.1250909363908439
# Epoch 92000, Loss: 0.12509045734672308
# Epoch 93000, Loss: 0.12508998328332654
# Epoch 94000, Loss: 0.12508951412367558
# Epoch 95000, Loss: 0.12508904979236535
# Epoch 96000, Loss: 0.12508859021552549
# Epoch 97000, Loss: 0.125088135320781
# Epoch 98000, Loss: 0.12508768503721465
# Epoch 99000, Loss: 0.12508723929533072
# Predicted Output:
#  [[0.0075638 ]
#  [0.99199965]
#  [0.49993868]
#  [0.50016463]]
